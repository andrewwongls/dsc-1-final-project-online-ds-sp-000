# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Andrew Wong
# * Student pace: Self paced
# * Scheduled project review date/time:
# * Instructor name:

# %% [markdown]
# <img src="Making Sense of House Prices in King County.png">

# %% [markdown]
# # RESEARCH REPORT CONTENTS
#
# **BACKGROUND**
# <br>
# A Tour of King County - Geography, Population, and Social Makeup
# <br>
# <br>
# **DATA SCIENCE WORKFLOW AND LIBRARIES**
# <br>
# An Introduction to Various Data Science Workflow
# <br>
# An Introduction to Various Data Science Libraries
# <br>
# <br>
# **THE OSEMN DATA SCIENCE WORKFLOW**
# <br>
# <br>
# **THE KEY BUSINESS QUESTIONS - HOUSE PRICE CONTEXT**
# <br>
# Key Question
# <br>
# The Behavioural Questions
# <br>
# The Trend Questions
# <br>
# <br>
# **PART 1 OBTAINING THE DATA**
# <br>
# Initial Datasets Scanning
# <br>
# Initial Visualization Scanning
# <br>
# Summary of Part 1
# <br>
# <br>
# **PART 2 DATA SCRUBBING**
# <br>
# Remove '?' in the sqft_basement dataset.
# <br>
# Detecting and fixing missing values.
# <br>
# Investigating potential multicollinearity.
# <br>
# Removing unnecessary datapoints/ columns.
# <br>
# Transposing the appropriate datatypes
# <br>
# Summary of Part 2
# <br>
# <br>
# **PART 3 EXPLORING THE DATA**
# <br>
# Strategy to explore the new scrubbed data
# <br>
# Understanding Correlationship through Jointplot, Spearman Correlation, and p-Value
# <br>
# Summary of Part 3
# <br>
# <br>
# **PART 4 MODELLING THE DATA**
# <br>
# Strategy to model the data
# <br>
# Train and test split
# <br>
# Improving the modelling fitness
# <br>
# Fitting the model
# <br>
# Summary of Part 4
# <br>
# <br>
# **PART 5 INTERPRETING THE DATA**
# <br>
# Explanatory power of the model
# <br>
# Influencing power of the individual variables, within the context of House Sale Domain Knowledge
# <br>
# <br>
# **CONCLUDING REMARKS**
# <br>
# The current model
# <br>
# Improvement for future research exploration

# %% [markdown]
# # BACKGROUND
#
# ## A Tour of King County - Geography, Population and Social Makeup

# %% [markdown]
# The latest census of King County's population (2017) is estimated to be around 2.188 millions, with a 13.3% population growth since 2010. The race majority of King County are White, with about 21.6% of the populations are foreign born persons.
#
# The table below provide some context for the readers of this document, with specific information on housing, education levels, income and poverty level, population and geography, and families and living arrangements. These information are important to take into broader context when we are trying to predict house sale price because the characteristics of the house alone are not the only determining factors.

# %% [markdown]
# <img src='King County Statistics.png'>

# %% [markdown]
# # DATA SCIENCE WORKFLOW AND LIBRARIES

# %% [markdown]
# ## DATA SCIENCE WORKFLOW
#
# Prior to the start of any data science project/research, it is advisable to follow an iterative discipline of getting data, scrubbing the data, exploring the data, and finally modelling the data for their predictive purpose.
#
# There are plentiful data science workflows being used by data scientists, researchers, and data analysts. The workflows shown below are some of the more popular data science workflows. Here's a brief description of their unique characteristics:
#
# **1. Harvard Data Science Workflow:** This workflow centers on business questions to drive data analysis. By asking powerful questions, this model drive better data context.
#
# **2. KDD Workflow: The Knowledge Discovery in Databases (KDD):** workflow centers on complext data discovery, especially in legacy data warehouse systems.
#
# **3. CRISP-DM Workflow:** The Cross-Industry Standard Process for Data Mining (CRISP-DM) workflow centers on iterative data analysis. It is based on a simple approach of bringing analytics to production in a business-oriented and systematic way.
#
# **4. Data Journalism Workflow:** This is a very interesting workflow because it centers around storytelling, and sharing of information through visual, and always thinks about the readers context.
#
# **5. OSEMN Workflow:** This workflow centers on a rapid, iterative data discovery, scrubbing, exploration, modelling, and interpretation.

# %% [markdown]
# <img src='Various Data Science Workflows.png'>

# %% [markdown]
# ## DATA SCIENCE LIBRARIES - PYTHON

# %% [markdown]
# **PANDAS**
# It is a library written for data manipulation and analysis in Python. It offers data structures and operations for manipulating numerical tables and time series.
#
# **SCIKIT-LEARN**
# Scikit-learn support for large, multi-dimensional arrays and matrices, along with a large library of high-level mathematical functions to operate on these arrays.
#
# **SCIPY**
# SciPy is a collection of mathematical algorithms and convenience functions built on top of Numpy extension. It adds significant power to the Python session by providing the user with high-level commands and classes for manipulating and visualizing data.
#
# **MATPLOTLIB**
# This is a 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms.
#
# **NUMPY**
# It supports for large, multi-dimensional arrays and matrices, along with a large library of high-level mathematical functions to operate on these arrays.
#
#
# **SEABORN**
# It is a data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# # THE OSEMN DATA SCIENCE WORKFLOW
#
# This data science project will use the OSEMN data science workflow. The followings are the summary of the steps taken:
#
# **STEP 1 OBTAINING THE DATA**
# <br>
# Importing relevant python libraries
# <br>
# Initial data scanning
# <br>
# Initial data visualization scanning
# <br>
# <br>
# **STEP 2 SCRUBBING THE DATA**
# <br>
# Remove '?' in the sqft_basement dataset.
# <br>
# Detecting and fixing missing values.
# <br>
# Investigating potential multicollinearity.
# <br>
# Transposing to the appropriate datastype
# <br>
# Removing unnecessary datapoints/ columns.
# <br>
# <br>
# **STEP 3 EXPLORING THE DATA**
# <br>
# Strategizing on how to explore the newly scrubbed data
# <br>
# Understanding the correlationship between jointplot, spearman correlation, p-Value
# <br>
# <br>
# **STEP 4 MODELLING THE DATA**
# <br>
# Train and test split
# <br>
# Improving the modelling fitness
# <br>
# Fitting the model
# <br>
# <br>
# **STEP 5 INTERPRETING THE DATA**
# <br>
# Explantory power of regression model
# <br>
# Influencing power of the individual variables

# %% [markdown]
# ## KEY QUESTION
#
# 1. What are the predictive power of independent variables such number of house viewing, number of bedrooms, zipcode and others on the house sale price of a house?
#
# ## THE BEHAVIOURAL QUESTIONS - IN HOUSE PRICE CONTEXT
# 1. What type of lifestyle choices of house buyers prefer?
# 2. What are the highly desirable zipcode or geography in King County?
# 3. What are the key house design characteristics that are highly attractive to house buyers in King County?
#
# ## THE TREND QUESTIONS - IN HOUSE PRICE CONTEXT
#
# 1. What are the latest house price trends in King County vs whole of US?
# 2. What are the trends in housing construction?
# 3. What is driving demand and supply of bigger or smaller house?

# %% [markdown]
# # PART 1 OBTAINING THE DATA

# %%
# importing relevant python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits

# %matplotlib inline

# %% [markdown]
# ## INITIAL DATASETS SCANNING

# %%
# reading data as DataFrame and check first 10 rows
house_data=pd.read_csv('kc_house_data.csv')
house_data.head(20)
# Out:
#             id        date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  10/13/2014   221900.0         3       1.00         1180
# 1   6414100192   12/9/2014   538000.0         3       2.25         2570
# 2   5631500400   2/25/2015   180000.0         2       1.00          770
# 3   2487200875   12/9/2014   604000.0         4       3.00         1960
# 4   1954400510   2/18/2015   510000.0         3       2.00         1680
# 5   7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6   1321400060   6/27/2014   257500.0         3       2.25         1715
# 7   2008000270   1/15/2015   291850.0         3       1.50         1060
# 8   2414600126   4/15/2015   229500.0         3       1.00         1780
# 9   3793500160   3/12/2015   323000.0         3       2.50         1890
# 10  1736800520    4/3/2015   662500.0         3       2.50         3560
# 11  9212900260   5/27/2014   468000.0         2       1.00         1160
# ...

# %% [markdown]
# The dataset table above shown 21 variables, and there are some missing data (NaN) found in dataset waterfront, view, and yr_renovated. The sqft_basement column has some peculiar variables in the form of '?' and '0.0', this needs to be investigated further.

# %%
# getting a summary of the data
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %% [markdown]
# The summary of datatypes above has shown some peculiarity that could be caused by error in determining whether a datatype has categorical, integer or float datatypes.

# %%
# checking for any missing information
house_data.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# Based on the variables above, the waterfront, view, and year renovated contains missing data values. This need to be addressed in during data scrubbing stage.

# %% [markdown]
# ## INITIAL VISUALIZATION SCANNING

# %% [markdown]
# ### LONGITUDE AND LATITUDE

# %% [markdown]
# The visualization below illustrates the longitude and latitude of houses in King County. A quick comparison between the visual below and the map of King Country has shown than the house closer to the water, the higher they can command higher prices. This is not usual given the lifestyle of the richer individuals or families prefer water features/scenery.
#
# The longitude and latitude data should be similar with zipcode data. The zipcode data could be more valuable than longitude and latitude data because zipcode data provide good enough precision.

# %%
# using scatter plot to map the longitude and latitude of King County
house_data.plot(kind='scatter', x='long', y='lat', alpha=.5, figsize=(20,15), c='price', cmap='viridis', sharey=True, sharex=False);

# %% [markdown]
# ### BEDROOMS
#
# The histogram below shows a majority of houses have 3 bedrooms.

# %%
# running some quick data analysis using bar chart
house_data['bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter diagram below shows the relationship between price and number of bedrooms. Initial review shows that the relationship between bedrooms and house price are concentrated between 2 and 6 bedrooms, with one exception anomaly of 34 bedrooms

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.bedrooms, house_data.price)
plt.title('Bedrooms vs House Price')
# Out:
# Text(0.5, 1.0, 'Bedrooms vs House Price')

# %% [markdown]
# ### BATHROOMS
#
# The histogram below shows a majority of houses have 2.5 bathrooms. Given the above bedrooms and bathrooms relationship, this seems like a normal/well-balanced house design, close to 1:1 matching of number of bedrooms and bathrooms.
#
# Based on an Internet search, the following are for reference in terms of how bathrooms are calculated:
# 1. Full bathroom (i.e. ensuite) is equal to 1 bathroom.
# 2. Half-bathroom (i.e. separate) is equal to 0.5 bathroom.
# 3. Powder room (i.e. only toilet and sink) is equal to 0.25 bathroom.

# %%
# running some quick data analysis using bar chart
house_data['bathrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bathrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter diagram below shows house price and number of bathrooms relationships.
#
# A quick scan of the scatter diagram below shows a form of heteroscedasticity. This means there is variability of a variable is unequal across the range of values of a second variable that predicts it. A scatterplot House Sale Price and Bedrooms variables will often create a cone-like shape, as the scatter (or variability) of the dependent variable (DV; Price) widens or narrows as the value of the independent variable (IV; Bedroom) increases.
#
# For more details explanation about heteroscedasticity, please refer to this blog:
# http://www.statsmakemecry.com/smmctheblog/confusing-stats-terms-explained-heteroscedasticity-heteroske.html

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.bathrooms, house_data.price)
plt.title('Bathrooms vs House Price')
# Out:
# Text(0.5, 1.0, 'Bathrooms vs House Price')

# %% [markdown]
# ### SQUARE FOOT LIVING
# The histogram below shows a long-tailed data points of square foot living.

# %%
# running some quick data analysis using histogram
house_data['sqft_living'].value_counts().plot(kind='hist')
plt.title('Square Foot Living')
plt.xlabel('Square Foot Living')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter diagram below shows house price and square foot living relationships.
# A quick scan of the scatter diagram below shows an even stronger form of heteroscedasticity, as evidenced by the cone shaped scatter plot.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.sqft_living, house_data.price)
plt.title('Square Foot Living vs House Price')
# Out:
# Text(0.5, 1.0, 'Square Foot Living vs House Price')

# %% [markdown]
# ### SQUARE FOOT LOT

# %% [markdown]
# The histogram below shows the most of the houses are below 50 square foot lot.

# %%
# running some quick data analysis using histogram
house_data['sqft_lot'].value_counts().plot(kind='hist')
plt.title('Square Foot')
plt.xlabel('Square Foot Lot')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# running some quick data analysis using scater plot
plt.scatter(house_data.sqft_lot, house_data.price)
plt.title('Square Foot Lot vs House Price')
# Out:
# Text(0.5, 1.0, 'Square Foot Lot vs House Price')

# %% [markdown]
# ### FLOORS

# %% [markdown]
# The bar chart below illustrates that most of King County's houses are one or two storeys, which is a common house design in many parts of USA. Some of the houses have 1.5 or 2.5 floors, which indicates some form of mezzanine floor design.

# %%
# running some quick data analysis using bar chart
house_data['floors'].value_counts().plot(kind='bar')
plt.title('Floors')
plt.xlabel('Floors')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# It looks like 2 and 2.5 storeys command the highest house sale price, with a few outliers in 3.5 storeys.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.floors, house_data.price)
plt.title('Floors vs House Price')
# Out:
# Text(0.5, 1.0, 'Floors vs House Price')

# %% [markdown]
# ###  WATERFRONT

# %% [markdown]
# Most of the houses in Kind County have no waterfront features. This potentially increases the house prices because of the scarcity of supply i.e. human behaviour typically will lean towards wanting something that is hard to get such as a house near the water. Traditionally, a house near the water commands higher house sale price because of the adding water view and water lifestyle that's come with it such as sailing, etc.

# %%
# running some quick data analysis using bar chart
house_data['waterfront'].value_counts().plot(kind='bar')
plt.title('Waterfront')
plt.xlabel('Waterfront')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter plot below contradict to the earlier assumption of having a house near to water means a house can command a higher price, this scatter plot map the relationship between waterfront and price. There seems like no clear relationship.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.waterfront, house_data.price)
plt.title('Waterfront vs House Price')
# Out:
# Text(0.5, 1.0, 'Waterfront vs House Price')

# %% [markdown]
# ### VIEW

# %% [markdown]
# This bar chart below seems counterintuitive because typically a house buyer will view the house at least once or more. This is not the case here.

# %%
# running some quick data analysis using bar chart
house_data['view'].value_counts().plot(kind='bar')
plt.title('Number of House Viewing')
plt.xlabel('House Viewing')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# There is no exact pattern that can be derived from this chart, other than it is fairly uniform i.e. there is zero house viewing to an exterme of 4 house viewing.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.view, house_data.price)
plt.title('View vs House Price')
# Out:
# Text(0.5, 1.0, 'View vs House Price')

# %% [markdown]
# ### HOUSE CONDITION

# %% [markdown]
# The bar chart below shows most of King County houses condition are around 3, which is not great and not bad either.

# %%
# running some quick data analysis using bar chart
house_data['condition'].value_counts().plot(kind='bar')
plt.title('House Condition')
plt.xlabel('House Condition')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter below not telling us much whether there is a strong relationship between house condition and house price.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.condition, house_data.price)
plt.title('Condition vs House Price')
# Out:
# Text(0.5, 1.0, 'Condition vs House Price')

# %% [markdown]
# ### HOUSE GRADE

# %% [markdown]
# The bar chart below shows a majority of houses in King County are graded fairly high, which indicates that the homeowners are sufficiently well-off to maintain house quality through renovation or routine maintanence.

# %%
# runing some quick data analysis using bar chart
house_data['grade'].value_counts().plot(kind='bar')
plt.title('House Grade')
plt.xlabel('House Grade')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter plot below tells a good correlationship story that better house grade commands better house sale price.

# %%
# run some quick data analysis using scatter plot
plt.scatter(house_data.grade, house_data.price)
plt.title('Grade vs House Price')
# Out:
# Text(0.5, 1.0, 'Grade vs House Price')

# %% [markdown]
# ### SQUARE FOOT ABOVE

# %% [markdown]
# The histogram below shows more of King County houses are 50 square foot (above floors), with a very long tails of other houses of various square foot.

# %%
# running some quick data analysis using histogram chart
house_data['sqft_above'].value_counts().plot(kind='hist')
plt.title('Square Foot Above')
plt.xlabel('Square Foot Above')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter plot below indicates Heteroscedasticity relationship between square foot above and price.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.sqft_above, house_data.price)
plt.title('Square Foot Above vs House Price')
# Out:
# Text(0.5, 1.0, 'Square Foot Above vs House Price')

# %% [markdown]
# ### SQUARE FOOT BASEMENT

# %% [markdown]
# The histogram below shows quite a constrasting pattern to square foot above, there is no long tail. This indicates that there is a standard size of basement for most houses in King County - this could be require by law (i.e. basement size cannot be more than X square foot because of safety reason) or something else.

# %%
# running some quick data analysis using histogram chart
house_data['sqft_basement'].value_counts().plot(kind='hist')
plt.title('Square Foot Basement')
plt.xlabel('Square Foot Basement')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.sqft_basement, house_data.price)
plt.title('Square Foot Basement vs House Price')
# Out:
# Text(0.5, 1.0, 'Square Foot Basement vs House Price')

# %% [markdown]
# ### YEAR HOUSE WAS BUILT

# %% [markdown]
# The bar chart below shows a continuous data points of house year built, a good indication of houses are being build in King County through the decades, with higher frequency of houses being built in the latter years, probably due to population growth (close to 6% year-on-year, according to King County's statistics).

# %%
# running some quick data analysis using bar chart
house_data['yr_built'].value_counts().plot(kind='bar')
plt.title('Year Built')
plt.xlabel('Year Built')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The similarly with the bar chart above, scatter plot below shows a consistent house being built through the decades, and there is no clear relationship between year built and price, this needs to be investigated further.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.yr_built, house_data.price)
plt.title('Year Built vs House Price')
# Out:
# Text(0.5, 1.0, 'Year Built vs House Price')

# %% [markdown]
# ### YEAR HOUSE WAS RENOVATED

# %% [markdown]
# The histogram below shows no clear answer, there are probably missing values or something else. The data needs to be investigated further.

# %%
# running some quick data analysis using histogram
house_data['yr_renovated'].value_counts().plot(kind='hist')
plt.title('Year Renovated')
plt.xlabel('Year Renovated')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.yr_renovated, house_data.price)
plt.title('Year Renovated vs House Price')
# Out:
# Text(0.5, 1.0, 'Year Renovated vs House Price')

# %% [markdown]
# ### ZIPCODE

# %% [markdown]
# The histogram below runs through all the zipcode count, the assumption here is that it linked closely to the waterfront data - the smaller the zipcode count means it is closer to the water.

# %%
# running some quick data analysis using histogram
house_data['zipcode'].value_counts().plot(kind='bar')
plt.title('Zipcode')
plt.xlabel('Zipcode')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The scatter plot below shows quite a uniform set of relationship between zipcode and price. There are some clear higher house prices with zipcode that starts with 98000 and 98025.

# %%
# running some quick data analysis using scatter plot
plt.scatter(house_data.zipcode, house_data.price)
plt.title('Zipcode vs House Price')
# Out:
# Text(0.5, 1.0, 'Zipcode vs House Price')

# %% [markdown]
# ## SUMMARY OF PART 1
#
# 1. There are 21 variables. There are 19 variables can be considered as predictor variables. There are 2 variables should be taken out. First, ID variable has no predictor value. Second, price variable is our target variable.
# 2. There are missing data values in columns waterfront, view, and yr_renovated.
# 3. There are errors in characterizing datatypes. The variables condition, grade, and zipcode should be categorical variables.

# %% [markdown]
# ## PART 2 DATA SCRUBBING

# %% [markdown]
# The data scrubbing part (also known as data preparation) is a crucial step of the data science process for preparing the right foundation for further data exploration and insight. Data scrubbing part of the data science process is crucial to ensure that it is formatted nicely and adheres to specific set of rules.
# <br>
# Based on the insights gained from Part 1 Obtaining the Data, the following 5 steps are necessary to scrub the data:
# 1. Remove '?' in the sqft_basement dataset.
# 2. Detecting and fixing missing values.
# 3. Investigating potential multicollinearity.
# 4. Removing unnecessary datapoints/ columns.
# 5. Transposing to appropriate datatypes.

# %% [markdown]
# ### 1.1 DETERMINING AND REMOVING '?'

# %%
# in Part 1 - Obtaining the Data, a quick scan of the dataset shows sqft_basement column has a number of '?', which could be a problem for future data analysis
# checking the count for '?' in sqft_basement
house_data['sqft_basement'].value_counts().nlargest(10)
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
# 400.0       184
# 1000.0      148
# 900.0       142
# 300.0       142
# Name: sqft_basement, dtype: int64

# %%
# there are about 454 count of '?', therefore there is a need to replace with Zero.
house_data['sqft_basement'] = (house_data['sqft_basement'].replace('?', 0)).astype('float64')
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null float64
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %% [markdown]
# ### 1.2 DETECT AND FIX MISSING VALUE

# %% [markdown]
# There are 3 columns with missing values - waterfront, view, and yr_renovated

# %%
# checking for missing values
house_data.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
# replacing View NaN with Zero
house_data['view'].replace(np.nan, '0', inplace = True)

# replacing Waterfront and Year Renovated's NaN with median values
house_data['waterfront'].fillna(house_data['waterfront'].median(), inplace = True)
house_data['yr_renovated'].fillna(house_data['yr_renovated'].median(), inplace = True)    
house_data.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### 1.3 INVESTIGATING POTENTIAL MULTICOLLINEARITY

# %% [markdown]
# The heatmap below shows correlationship among variables. The darker the color, the higher correlationship between two variables.
# <br>
# In this King County dataset, bedrooms, grade, square foot living, and square foot above shows high correlationship with each others.
# <br>
# Based on the multicollinearity analysis, and a fair of research into house characteristics (understanding the housing domain knowledge - the insider knowledge), the following actions are taken:
# 1. Maintain sqft_living, and removing sqft_above and sqft_basement because sqft_living dataset should be a consolidation of both sqft_above and sqft_basement.
#
# 2. Maintain grade and bedrooms because both house characteristics are important determining factors for housebuyers.

# %%
# using seaborn to plot heatmap. 
f, ax = plt.subplots(figsize=(15,12))

sns.heatmap(house_data.corr(), center=0, linewidths=.8, cmap="YlGnBu");

# %% [markdown]
# ### 1.4 REMOVING UNNECESSARY COLUMNS

# %%
# removing unnecessary columns using the drop function
def drop_cols(columns, house_data):
    
    return house_data.drop(columns, axis=1, inplace=True)

drop_cols(['id', 'date', 'lat', 'long', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'sqft_above'], house_data)
house_data.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0         0.0
# 1  538000.0         3       2.25         2570      7242     2.0         0.0
# 2  180000.0         2       1.00          770     10000     1.0         0.0
# 3  604000.0         4       3.00         1960      5000     1.0         0.0
# 4  510000.0         3       2.00         1680      8080     1.0         0.0
#
#   view  condition  grade  yr_built  yr_renovated  zipcode
# 0    0          3      7      1955           0.0    98178
# 1    0          3      7      1951        1991.0    98125
# 2    0          3      6      1933           0.0    98028
# 3    0          5      7      1965           0.0    98136
# 4    0          3      8      1987           0.0    98074

# %% [markdown]
# ### 1.5 TRANSPOSING TO APPROPRIATE DATATYPES

# %%
# sqft_basement datatype that has labelling error, this needs to be addressed for future data analysis
into_int = ['sqft_living', 'waterfront', 'view', 'yr_built', 'yr_renovated']
for var in into_int:
    house_data[var] = house_data[var].astype('int64')

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 13 columns):
# price           21597 non-null float64
# bedrooms        21597 non-null int64
# bathrooms       21597 non-null float64
# sqft_living     21597 non-null int64
# sqft_lot        21597 non-null int64
# floors          21597 non-null float64
# waterfront      21597 non-null int64
# view            21597 non-null int64
# condition       21597 non-null int64
# grade           21597 non-null int64
# yr_built        21597 non-null int64
# yr_renovated    21597 non-null int64
# zipcode         21597 non-null int64
# dtypes: float64(3), int64(10)
# memory usage: 2.1 MB

# %%
# transposing all categorical data into categorical-datatype
house_data.condition = house_data.condition.astype('category')
house_data.grade = house_data.grade.astype('category')
house_data.zipcode = house_data.zipcode.astype('category')

# %%
# one-hot encoding
condition_dummies = pd.get_dummies(house_data.condition, prefix='condition').iloc[:,1:]
grade_dummies = pd.get_dummies(house_data.grade, prefix='grade').iloc[:,1:]
zipcode_dummies = pd.get_dummies(house_data.zipcode, prefix='zipcode').iloc[:,1:]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 13 columns):
# price           21597 non-null float64
# bedrooms        21597 non-null int64
# bathrooms       21597 non-null float64
# sqft_living     21597 non-null int64
# sqft_lot        21597 non-null int64
# floors          21597 non-null float64
# waterfront      21597 non-null int64
# view            21597 non-null int64
# condition       21597 non-null category
# grade           21597 non-null category
# yr_built        21597 non-null int64
# yr_renovated    21597 non-null int64
# zipcode         21597 non-null category
# dtypes: category(3), float64(3), int64(7)
# memory usage: 1.7 MB

# %% [markdown]
# ## SUMMARY OF PART 2
#
# The data scrubbing exercise is necessary to prepare for the next stage - data exploration.
# There are 5 steps taken to scrub data:
# 1. Determining and removing '?' in sqft_basement dataset.
#
# 2. Detecting and fixing missing values for view, waterfront, and yr_renovated.
#     a. For view column, there is a only a small amount of data, therefore it is reasonable to replace with zero.
#     b. For waterfront column, it is reasonable to replace with median value.
#     c. For yr_renovated column, it is unclear of the reasoning behind NaN and 0.0 data points. The
#     assumption here is either the house has not been renovated before or there is no data (acted as a
#     placeholder). There is reasonable to replace with median value.
#
# 3. Investigate potential multicollinearity. The purpose is to understand and surface out independent data points (columns) that are correlated. This correlation is a problem because independent variables should be independent. If the degree of correlation between variables is high, it can cause problems when we are trying to fit the model and interpret the results.
#
# 4. Based on the above step (investigate potential multicollinearity) and reviewing of other independent data points, the followings columns are removed:
#     a. id
#     b. date
#     c. lat
#     d. long
#     e. sqft_basement
#     f. sqft_living15
#     f. sqft_lot15
#     g. sqft_above
#
# 5. Transposing a few datatypes to their appropriate categorical datatypes, namely condition, grade and zipcode.

# %% [markdown]
# # PART 3 EXPLORING THE DATA

# %% [markdown]
# ## STRATEGY TO EXPLORE THE NEWLY SCRUBBED DATA
#
# **Human Intuition**
# 1. Focus on the simple and big picture - keep asking why and so what.
# 2. Focus on being close to data and start to think like a home buyer - let yourself into a homebuyer's shoe.
#
# **Data Intuition**
# 1. Grounding the data and get closer to the data by reading deeper and wider about home sale and home buying patterns.
# 2. Data has its own opinion - it is real - however it sometimes can be counterintuitive. If it is counterintuitive, either go deeper into the data, or turn to broader behavioral, psychological, and economical contexts.

# %% [markdown]
# ### EXPLORING NEW SCRUBBED DATA

# %%
# checking non-categorical data to get a feel of the newly scrubbed data
new_data = ['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_living', 'yr_built', 'yr_renovated', 'zipcode']
fig = house_data[new_data].hist(bins=100, color='red', figsize=(10,10), grid=True)
plt.show();

# %% [markdown]
# ### UNDERSTANDING CORRELATIONSHIP THROUGH JOINTPLOT, SPEARMAN CORRELATION, AND p-VALUE

# %% [markdown]
# In order to explore our newly scrubbed data further, we will be running jointplot, spearman correlation, and p-Value. There are few rationales why we are running these three analysis. The following are a few explanations to get us going:
# 1. Jointplot is a way to display data points according to two variables, along with both their distributions, kernel density estimators, and an optional regression that fits the data. With kind 'reg', it means we want a regression fit to the data.
# 2. A Spearman correlation coefficient is also referred to as Spearman rank correlation or Spearman’s rho. It is like all correlation coefficients, Spearman measures the strength of association between two variables (similar to Pearson correlation coefficient). Furthermore, Spearman is quite flexible because it does not require continuous data, and can be used in many cases in which the assumptions of the Pearson correlation (continuous-level variables, linearity, heteroscedasticity, and normality) are not met. Spearman’s Rank correlation coefficient is a technique which can be used to summarise the strength and direction (negative or positive) of a relationship between two variables. The result will always be between 1 and minus 1.
# 2. The P-value is the probability that we would have found the current result if the correlation coefficient were in fact zero (null hypothesis). If this probability is lower than the conventional 5% (P<0.05) the correlation coefficient is called statistically significant.

# %% [markdown]
# Addition reference guide for correlationship:
#
# 1. Exactly –1. A perfect downhill (negative) linear relationship
# 2. –0.70. A strong downhill (negative) linear relationship
# 3. –0.50. A moderate downhill (negative) relationship
# 4. –0.30. A weak downhill (negative) linear relationship
# 5. 0. No linear relationship
# 6. +0.30. A weak uphill (positive) linear relationship
# 7. +0.50. A moderate uphill (positive) relationship
# 8. +0.70. A strong uphill (positive) linear relationship
# 9. Exactly +1. A perfect uphill (positive) linear relationship
#
# For more reference information, read the following link: https://www.dummies.com/education/math/statistics/how-to-interpret-a-correlation-coefficient-r/

# %% [markdown]
# **FURTHER NOTES ABOUT CORRELATIONSHIP AND STATISTICALLY SIGNIFICANCE**
# <br>
# Statistical significance will be more dependent on the sample size than on the degree of correlation/determination. For example - a very large sample sizes with almost no collinearity, it could be highly statistically significant results, and vice versa
# <br>
# If we happen to look at variables that may have high degree of correlation but the resultant change in process or practice makes little to no practical significance, then we should be asking the 'so what?'

# %% [markdown]
# #####  BEDROOMS AND PRICE JOINTPLOT - WEAK UPHILL POSITIVE CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Bedrooms and Price. The bedrooms looks like a multimodal relationships with a few peaks. Wherelse, house price is unimodal. There is a positive correlation between the two variables as shown by the red regression line.
# <br>
# <br>
# In this case below, it appears to be an upward tendency shown by the regression, there appears to be weak positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A close to zero Pearson correlation coefficient indicates that the two are statistically significant.

# %%
# using seaborn to call out jointpoint diagram
import scipy.stats as stats
from scipy.stats import spearmanr
sns.jointplot(x='bedrooms', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='bedrooms', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### SQUARE FOOT LOT AND PRICE JOINTPLOT - WEAK UPHILL POSITIVE CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Square Foot Lot and Price. The Square Foot Lot looks like a unimodal relationships with a peak.
#
# In this case below, it appears to be an upward tendency shown by the regression, there appears to be weak positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A high Pearson correlation coefficient indicates that the two are not statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='sqft_lot', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='sqft_lot', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# #####  FLOORS AND PRICE JOINTPLOT - CLOSE TO NO CORRELATIONSHIP

# %% [markdown]
# The jointplot below shows the relationship between Floors and Price. The Square Foot Lot looks like a multimodal relationships with a few peaks.
#
# In this case below, it appears to be an upward tendency shown by the regression, there appears to be very weak positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A high Pearson correlation coefficient indicates that the two are statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='floors', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='floors', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### WATERFRONT AND PRICE JOINTPLOT - WEAK UPHILL POSITIVE CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Waterfront and Price. The bedrooms looks like an unimodal relationships with a peak. Wherelse, house price is unimodal. There is a positive correlation between the two variables as shown by the red regression line.
# <br>
# <br>
# In this case below, it appears to be an upward tendency shown by the regression, there appears to be weak positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A high Pearson correlation coefficient indicates that the two are not statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='waterfront', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='waterfront', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### CONDITION AND PRICE JOINTPLOT - CLOSE TO NO CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Condition and Price. The Condition looks like a multimodal relationships with a few peaks.
# <br>
# In this case below, t appears to be an upward tendency shown by the regression, it appears to be weak positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A close to zero Pearson correlation coefficient indicates that the two are statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='condition', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='condition', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### GRADE AND PRICE JOINTPLOT - STRONG UPHILL POSITIVE CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Grade and Price. The Grade looks like a multimodal relationships with a few peaks.
# <br>
# In this case below, it appears to be an upward tendency shown by the regression, it appears to be strong positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A close to zero Pearson correlation coefficient indicates that the two are statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='grade', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='grade', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### YEAR BUILT AND PRICE JOINTPLOT - CLOSE TO NO CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Year Built and Price. The Year Built looks like a multimodal relationships with a few peaks.
# <br>
# In this case below, it appears to be flat shown by the regression, it appears to be no correlation between the variables (as confirmed by Spearmans coefficient). A high Pearson correlation coefficient indicates that the two are statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='yr_built', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='year_built', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### YEAR RENOVATED AND PRICE JOINTPLOT - WEAK UPHILL POSITIVE CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Year Renovated and Price. The Year Renovated looks like a uniimodal relationships with a few peaks.
# <br>
# In this case below, it appears to be an almost flat line shown by the regression, it appears to be weak positive uphill correlation between the variables (as confirmed by Spearmans coefficient). A high Pearson correlation coefficient indicates that the two are not statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='yr_renovated', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='yr_renovated', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ##### ZIPCODE AND PRICE JOINTPLOT - WEAK DOWNHILL NEGATIVE CORRELATION

# %% [markdown]
# The jointplot below shows the relationship between Condition and Price. The Condition looks like a multimodal relationships with a few peaks.
# <br>
# In this case below, it appears to be an weak downhill tendency shown by the regression, it appears to be weak downhill correlation between the variables (as confirmed by Spearmans coefficient). A slightly high Pearson correlation coefficient indicates that the two are not statistically significant.

# %%
# using seaborn to call out jointpoint diagram
sns.jointplot(x='zipcode', y='price', data=house_data, stat_func=spearmanr, kind='reg', label='zipcode', joint_kws={'line_kws':{'color':'red'}})
plt.show()
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [markdown]
# ## SUMMARY OF PART 3
#
# This section provides reader a good context or sense of available data for next step - modelling the data.

# %% [markdown]
# # PART 4 MODELLING

# %% [markdown]
# ## STRATEGY TO MODEL THE DATA

# %% [markdown]
# 1. Train and test split
# 2. Improving the modelling fitness
# 3. Fitting the model

# %% [markdown]
# ### TRAIN AND TEST SPLIT

# %%
# splitting the train and test set into 75/25 split
from sklearn.model_selection import train_test_split
trainset = house_data.drop('price', axis = 1)
testset = house_data[['price']]
trainset_train, trainset_test, testset_train, testset_test = train_test_split(trainset, testset, test_size = 0.25, random_state=10)

# %% [markdown]
# #### CALCULATING AND INTERPRETING MSE RESULTS

# %%
# checking the MSE 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np

linreg = LinearRegression()
linreg.fit(trainset_train, testset_train)
yhat_train = linreg.predict(trainset_train)

lm = LinearRegression()

# calculating the MSE
train_mse = mean_squared_error(testset_train, yhat_train)
print('MSE: ', train_mse)
# Out:
# MSE:  47470458649.40424

# %% [markdown]
# #### CALCULATING AND INTERPRETING OLS RESULTS
#
# We will be using OLS (Ordinary Least Square), and the followings are some instructions on how to interpreting the plentiful OLS results.
#
# The model performance are located at the top table - R-square and adjusted R-squared.
# <br>
# The model significance information is located at the top table - F-statistics and p-Value
# <br>
# The explanatory of each variables information is located in the middle table - from bedrooms to zipcode.
# <br>
# The model bias information is located at the bottom of the table - Jarque-Bera (JB) and Durbin-Watson.

# %%
# calculating the OLS
import statsmodels.api as sm
from statsmodels.formula.api import ols

predictors_int = sm.add_constant(trainset_train)
model = sm.OLS(testset_train, predictors_int.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     2542.
# Date:                Mon, 26 Nov 2018   Prob (F-statistic):               0.00
# Time:                        20:32:54   Log-Likelihood:            -2.2207e+05
# No. Observations:               16197   AIC:                         4.442e+05
# Df Residuals:                   16184   BIC:                         4.443e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### MODEL PERFORMANCE
# Both the Multiple R-Squared and Adjusted R-Squared values are measures of model performance. Possible values range from 0.0 to 1.0. The Adjusted R-Squared value is always a bit lower than the Multiple R-Squared value, because it reflects model complexity (the number of variables) as it relates to the data and is consequently a more accurate measure of model performance. Adding an additional explanatory variable to the model will likely increase the Multiple R-Squared value but may decrease the Adjusted R-Squared value.
#
# An Adjusted R-Squared value of 0.65 would indicate that the current model (the explanatory variables modeled using linear regression) explains approximately 62 percent of the variation in the dependent variable. Said another way, the current model explain approximately 65 percent of the house price.

# %% [markdown]
# ##### MODEL SIGNIFICANCE
#
# The F-test sums the predictive power of all independent variables and determines that it is unlikely that all of the coefficients equal zero. However, it is possible that each variable is not predictive enough on its own to be statistically significant. In other words, the sample provides sufficient evidence to conclude that the current model is significant, but not enough to conclude that any individual variable is significant. This finding is good news because it is sufficiently high.

# %% [markdown]
# #####  EXPLANATORY POWER OF INDEPENDENT VARIABLES
#
# The p-value for all independent variables is less than the significance level, which means that the current independent variables provide sufficient evidence to conclude that the regression model fits the data better than the model with no independent variables. This finding is good news because it means that the independent variables in the current model improve the fit.
#
# A read of the coefficient column shows three variables are negatively related with house sale price i.e.
# 1. Number of bedrooms - this seems counter-intuitive because typically a higher number of bedrooms means more space for family. Perhaps the number of bedrooms increase has a positive benefits to homebuyer up to a certain threshold i.e. why do I want more than 6 bedrooms if I have only 2 children.
# 2. Year built - it looks like homebuyers in King County value newer houses.
# 3. Zipcode - we can ignore this because it is no relevant.

# %% [markdown]
# #####  MODEL BIAS
#
# The Jarque-Bera (JB) statistic indicates whether or not the residuals (i.e. the known dependent variable values minus the predicted values) are normally distributed. Put simply, it is a test to confirm normality.
#
# When the p-value (probability) for this test is small (smaller than 0.05 for a 95 percent confidence level, for example), the residuals are not normally distributed, indicating the current model is biased. In general, a large JB value, in this current model, indicates that errors are not normally distributed.
#
# The Durbin Watson statistic is a number that tests for autocorrelation in the residuals from a statistical regression analysis. The Durbin-Watson statistic is always between 0 and 4. The current model has a value of 2 means that there is no autocorrelation in the sample.

# %% [markdown]
# #####  MODEL SYMMETRY
#
# Skewness implies off-centre (i.e. it means lack of symmetry). The skewness value can be positive or negative, or even undefined. If skewness is 0, the data are perfectly symmetrical, although it is quite unlikely for real-world data. As a general rule of thumb: If skewness is less than -1 or greater than 1, the distribution is highly skewed. In this current model, it is greater than 1, indicated a highly skewed distribution.
#
#
# Kurtosis refers to the pointedness of a peak in the distribution curve. The value is often compared to the kurtosis of the normal distribution, which is equal to 3. If the kurtosis is greater than 3, then the dataset has heavier tails than a normal distribution (more in the tails). In this current model, the value is greater than 3, indicated a dataset has heavier tails than normal distribution.

# %% [markdown]
# ### IMPROVING THE MODELLING FITNESS

# %% [markdown]
# #### GRADIENT BOOSTING
#
# The idea of boosting came out of the idea of whether a weak learner can be modified to become better. Is is an efficient algorithm for converting relatively poor hypotheses into very good hypotheses. A weak hypothesis or weak learner is defined as one whose performance is at least slightly better than random chance.
#
# Hypothesis boosting was the idea of filtering observations, leaving those observations that the weak learner can handle and focusing on developing new weak learns to handle the remaining difficult observations.This framework was further developed by Friedman and called Gradient Boosting Machines. Later called just gradient boosting.
#
# Gradient Boosting involves three elements:
# 1. A loss function to be optimized.
# 2. A weak learner to make predictions.
# 3. An additive model to add weak learners to minimize the loss function.

# %%
# attempting to import model fit through gradient boosting
import sklearn as sk
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 100, max_depth = 5, min_samples_split = 3, learning_rate = 0.05, loss = 'ls')
clf.fit(trainset, testset)
clf.score(trainset, testset)
# Out:
# C:\Users\awong\AppData\Local\Continuum\anaconda3\envs\learn-env\lib\site-packages\sklearn\utils\validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.867876638573723

# %% [markdown]
# The Gradient Boosting does not seems improve the current model fitness

# %%
# checking the MSE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

linreg = LinearRegression()
linreg.fit(trainset_train, testset_train)
yhat_train = linreg.predict(trainset_train)

train_mse = mean_squared_error(testset_train, yhat_train)
print('MSE: ', train_mse)
# Out:
# MSE:  47470458649.40424

# %%
# generating OLS
import statsmodels.api as sm
from statsmodels.formula.api import ols

predictors_int = sm.add_constant(trainset_train)
model = sm.OLS(testset_train, predictors_int.astype(float)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     2542.
# Date:                Mon, 26 Nov 2018   Prob (F-statistic):               0.00
# Time:                        20:33:03   Log-Likelihood:            -2.2207e+05
# No. Observations:               16197   AIC:                         4.442e+05
# Df Residuals:                   16184   BIC:                         4.443e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# # PART 5 INTERPRETING THE DATA

# %% [markdown]
# ## EXPLANATORY POWER OF THE REGRESSION MODEL

# %% [markdown]
# Starting from Part 1 to 4, a major part of the activities are obtaining data, scrubbing data, and exploring data. At this point, we are looking at the data - the cold, hard way. It is a good approach because it is data-driven.
# <br>
# <br>
# The following few steps are to bring new insights by marrying house domain knowledge with the data and analysis that we have in hand. The purpose is to set out to put some bigger conclusions and data-driven analysis first, and then tell a story on broader issues.
# <br>
# <br>
# As a refresher, the followings are independent variables included in our model (and their respective coefficient and p-values) to predict the house sale price in King County.
# <br>
# **Coefficient**
# <br>
# 1. Bedrooms (coefficient of -3.7): Bedrooms dataset has negative coefficient with price.
# 2. Bathrooms (coefficient of 4.8): Bathrooms dataset has positive coefficient with price.
# 3. Square Foot Living (coefficient of 167): Square Foot Living dataset has strong positive coefficient with price.
# 4. Square Foot Lot (coefficient of -0.29): Square Foot Lot dataset has a weak negative coefficient with price.
# 5. Floors (coefficient of 2.33): Floors dataset has positive coefficient with price.
# 6. Waterfront (coefficient of 6.48): Waterfront dataset has positive coefficient with price.
# 7. View (coefficient of 4.37): Bedrooms dataset has negative coefficient with price.
# 8. Condition (coefficient of 1.79): Condition dataset has positive coefficient with price.
# 9. Grade (coefficient of 1.26): Grade dataset has positive coefficient with price.
# 10. Year Built (coefficient of -3662): Year Built dataset has a very strong negative coefficient with price.
# 11. Year Renovated (coefficient of 7.6): Year Renovated dataset has positive coefficient with price.
# 12. Zipcode (coefficient of -65): Zipcode dataset has negative coefficient with price.
# <br>
#
# **p-Values**
# <br>
# <br>
# All of the indenpendent variables have small p-value (therefore they are statistically significant, except for year renovated (1.56) and zipcode (0.09), which indicated that they are not statistically significant.
# <br>
#
# **R-Square**
# <br>
# <br>
# The R-Square values is 0.65, which means the current model has an explanatory power of 65%. In another words, the 12 independent variables above are able to explain and predict the house sale price in King County. The other 35% influencing factors could be in form of others factor not covered in the King County House Sale Dataset.

# %% [markdown]
# ## INFLUENCING POWER OF INDIVIDUAL VARIABLES, WITHIN THE CONTEXT OF HOUSE SALE DOMAIN KNOWLEDGE
#
# **INDEPENDENT VARIABLES WITH POSITIVE CORRELATION COEFFICIENT WITH HOUSE SALE PRICE**
# <BR>
# <BR>
# Let's take a deeper dive into the influence of top 6 positive independent variables based on correlation coefficient, by layering some house sale domain knowledge assumptions.
#
# **Square Foot Living**: A bigger square foot living commands higher house price (the more living space, the better). This makes sense because naturally a larger living space provides more space for family or living flexibility e.g. a game room, cinema room, rumpus, etc. Therefore, house buyer will pay more for with larger living space flexibility and convenience.
# <br>
# <br>
# **Year Renovated**: The more recent renovated house, the better the house price (home buyers like it new, less hassle). This makes sense because typical house buyers like the convenience of moving into a house and enjoy the facility right away rather needing to worry about renovation hassle and of course additional renovation cost.
# <br>
# <br>
# **Waterfront**: A house near water feature / facility commands higher house price (water seems to relate to a more affluent lifestyle). Houses that located near water are limited in supply (especially in King County), and typically houses near water has higher visual attractiveness - blue and calm. More importantly, a house the water has added convenience advantage of water sport or water activities such as canoeing, boating, etc. (just take a stroll down the river/bay). Therefore, house buyer will pay more for a house near the water.
# <br>
# <br>
# **Bathrooms**: A house with sufficient bathrooms commands higher house price (the convenience of having bathroom choices seem like a good thing, especially if you have a big family). This makes sense because an additional one or two bathrooms translate into better convenience for family or visitors. Therefore, house buyer will pay more for a house with more bathrooms (of course up to a certain points).
# <br>
# <br>
# **Number of House Viewing**: A house that experienced a high rate of potential homebuyer viewing commands higher price (higher house view means it is attractive). This makes sense because if a house attracted higher house viewing, it means that there is a lot more interest for this particular house, as compared to a house with little interest (lower numbers of house viewing). In essence, competition (more interest) drive house price.
# <br>
# <br>
# **Floors**: A house with addition floors commands higher house sale price (who doesn't one additional living space, up to one point of course). Similar with square foot living, additional floors would means more living space convenience and flexibility.

# %% [markdown]
# **INDEPENDENT VARIABLES WITH NEGATIVE CORRELATION COEFFICIENT WITH HOUSE SALE PRICE**
# <br>
# <br>
# **Year Built**: Based on the earlier scatter plot analysis, the year built in King County are fairly uniform across a few decades. The coefficient data is counterintuitive.
# <br>
# <br>
# **Zipcode**: Based on the earlier scatter plot analysis, the zipcodes in King County are categorical. Therefore, the coefficient data is counterintuitive.
# <br>
# <br>
# **Bedrooms**: The number of bedrooms in a house seems to have a inverse affect on price, this is counterintuitive. More likely, the house design preferred by house buyers in King County have certain limit to their needs of an added bedrooms i.e. if you have 5 bedrooms already, will you pay for an addition 1 bedroom?
# <br>
# <br>

# %% [markdown]
# # CONCLUDING REMARKS

# %% [markdown]
# ## THE CURRENT MODEL

# %% [markdown]
# **INDEPENDENT VARIABLES** 65% Explanatory Power of the House Sale Price in King County
# <br>
# (Bedrooms + Bathrooms + Square Foot Living + Square Foot Lot + Floors + Waterfront + View + Condition + Grade + Year Built + Year Renovated + Zipcode)
# <br>
# <br>
# **THE OTHER INDEPENDENT VARIABLES** 35% Unexplainable Power
# <br>
# (Likely due to error in the model + other datapoints not part of the King County House Sale Price)

# %% [markdown]
# **Further notes on the other independent variables**
# <br>
# <br>
# On the errors in the model probably due to imperfect data scrubbing, wrong assumptions on multicollinearity, and wrong assumption of dropping dataset/columns.
# <br>
# <br>
# On the other datapoints not part of the King County House Sale Price, based on some Internet research, some factors that determine/ influence house sale price are not included in the dataset, but important are as follows:
# <br>
# **1. Attractivness of the street (emotion and physical characteristics)** - leafy and away of high volume traffic generally commands higher house sale price
# <br>
# **2. Proximity to school (physical characteristic)** - close to school means more convenience for children drop-off, and if a house in the school zone, generally it commands higher house sale price.
# <br>
# **3. Gentrification of an area that the house is located (emotion and physical characteristics)** - House buyers who are affluent, generally like to buy a house near to someone like them in wealth and lifestyle.
# <br>
# **4. Bank lending criteria (economic factor)** - Banks typically has restricted bank lending rules for certain location, this likely to impact house sale price or price growth of a house.

# %% [markdown]
# ## IMPROVEMENT FOR FUTURE RESEARCH EXPLORATION

# %% [markdown]
# Based on the experience/ insight so far from Part 1 (Obtaining the Data) to Part 5 (Interpreting the Data), we can derive lessons learned for improving future research exploration:
# <br>
# 1. Find simpler or alternative ways of improving model fitness. The current method use to improve model fitness (i.e. Gradient Boosting) did not seems to improve the current model.
# <br>
# 2. Import other new dataset and concatenate with current dataset.
# <br>
# 3. Experiment adding or removing current dataset to simulate different scenarios.
